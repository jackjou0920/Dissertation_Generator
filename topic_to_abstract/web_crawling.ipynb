# %%
import requests, time, MySQLdb, os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.alert import Alert
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.support import expected_conditions as EC

# %%
# driver = webdriver.Firefox()
# driver.get(url + 'index.html')

# wait(driver, 5).until(EC.alert_is_present())

# # Switch the control to the Alert window
# alert = driver.switch_to_alert()
# alert.send_keys("acp18dj" + Keys.TAB + "jack282505")
# alert.accept()
# time.sleep(5)
# html_doc = driver.page_source
# soup = BeautifulSoup(html_doc, 'html.parser')
# driver.close()
# driver.quit()

# %%
login_headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en,zh-TW;q=0.9,zh;q=0.8',
    'Authorization': 'Basic YWNwMThkajpqYWNrMjgyNTA1',
    'Cache-Control': 'no-cache',
    'Connection': 'keep-alive',
    'Cookie': '__utma=233425244.1247113454.1521441727.1521441727.1521441727.1; _ga_global=GA1.3.1247113454.1521441727',
    'Host': 'www.dcs.shef.ac.uk',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.87 Safari/537.36'
}

# %%
def get_page(url):
    requestsession = requests.Session()
    page = requestsession.get(url, headers=login_headers)
    page.encoding='utf-8'
    soup = BeautifulSoup(page.content, 'lxml')
    return soup

# %%
def load_page(year):
#     url = 'http://www.dcs.shef.ac.uk/intranet/archive/public/' + year + '/projects/msc/'
    url = 'http://www.dcs.shef.ac.uk/intranet/archive/public/' + year + '/projects/ug/'
#     if (year == '2017_2018'):
#         url = 'https://www.dcs.shef.ac.uk/intranet/archive/campus/2017_2018/projects/msc/' 
    main_soup = get_page(url)
    tables = main_soup.findAll('table')
    tab = tables[2]
    return url, tab

# %%
def parse_abst(url):
    abstract = ""
    abst_soup = get_page(url)
    abst_soup.encoding='utf-8'
    body = abst_soup.find(id='bodyContainer')
    for content in body.findAll('p'):
        abstract += content.getText()
    return abstract.strip()

# %%
def download_pdf(url, file):
    print("start download:", file)
    response = requests.get(url, headers=login_headers, stream="TRUE")
    print(response)
    with open('./pdf_file/'+file, 'wb') as file:
        for data in response.iter_content():
            file.write(data)
    print("download finish")

# %%
def save_db(rows):
    db = MySQLdb.connect(host="143.167.8.208", user="root", passwd="jack", db="dissertation")
    cursor = db.cursor()

    sql = "INSERT INTO Test(filename,topic,abstract) VALUES(%s,%s,%s)"
    try:
        cursor.executemany(sql, rows)
        db.commit()
    except MySQLdb.Error as e:
        print(e)

# %%
def write_file(path, text):
    with open(path, 'w') as out_file:
        out_file.write(text)

# %%
def check(filename, file, file_list, downloaded):
    if (filename in file_list) and (file not in downloaded):
        return True
    else:
        return False

# %%
def scraping_1(year, file_list, downloaded):
    url, tab = load_page(year)
    count = 0
    topic_path = './ug_dataset/topic/'
    abstract_path = './ug_dataset/abstract/'
    
    for tr in tab.tbody.findAll('tr'):
        dis_none = False
        idx = 0
        count += 1
        if(count == 1):
            continue
        filename = ""
        topic = ""
        abstract = ""
        c = 0
        for td in tr.findAll('td'):
            c += 1
        for td in tr.findAll('td'):
            idx += 1
            if (idx == 2):
                print(td.getText().strip())
            if (c == 7 and idx == 3):
                topic = td.getText().strip()
#             if (c == 7 and idx == 4):
#                 abt = td.find_all('a')
#                 if (len(abt) == 0):
#                     abstract = ""
#                 else:
#                     abst_url = url + abt[0]['href']
#                     abstract = parse_abst(abst_url)         
            if (c == 7 and idx == 5) or (c == 6 and idx == 4):
                dis = td.find_all('a')
                if (len(dis) == 0):
                    dis_none = True
                else:
                    is_none = False
                    dis_url = dis[0]['href']
#                     file = dis_url.replace('https://www.dcs.shef.ac.uk/intranet/archive/campus/'+year+'/projects/msc/', "")
                    file = dis_url.replace('https://www.dcs.shef.ac.uk/intranet/archive/campus/'+year+'/projects/ug/', "")
                    filename = file.replace(".pdf", "")
#                     print(filename)
        
                    if (check(filename+'.txt', file, file_list, downloaded)):
                        download_pdf(dis_url, file)
        
        
#         if (dis_none == False):
#             write_file(topic_path+filename+'.txt', topic)
#             write_file(abstract_path+filename+'.txt', abstract)
    
#     save to database
#     if (is_none):
#         data = (filename, topic, abstract)
#     else:
#         data = (filename, topic, abst)
#     rows.append(data)
#     if (count == 3):
#         break

# %%
def scraping_2(year, file_list, downloaded):
    url, tab = load_page(year)
    count = 0
    topic_path = './ug_dataset/topic/'
    abstract_path = './ug_dataset/abstract/'
    tab = tab.findAll('table')[0]
    
    for tr in tab.findAll('tr'):    
        dis_none = False
        idx = 0
        count += 1
        if(count == 1):
            continue

        filename = ""
        topic = ""
        abstract = ""
        c = 0
        for td in tr.findAll('td'):
            c += 1
        for td in tr.findAll('td'):
            idx += 1
            if (c == 7 and idx == 2) or (c == 5 and idx == 1):
                print(td.getText().strip())
            if (c == 7 and idx == 3) or (c == 5 and idx == 2):
                topic = td.getText().strip()
#             if (c == 7 and idx == 4):
#                 abt = td.find_all('a')
#                 if (len(abt) == 0):
#                     abstract = ""
#                 else:
#                     abst_url = url + abt[0]['href']
#                     abstract = parse_abst(abst_url)         
            if (c == 7 and idx == 5) or (c == 5 and idx == 4):
                dis = td.find_all('a')
                if (len(dis) == 0):
                    dis_none = True
                else:
                    is_none = False
                    dis_url = dis[0]['href']
#                     file = dis_url.replace('https://www.dcs.shef.ac.uk/intranet/archive/campus/'+year+'/projects/msc/', "")
                    file = dis_url.replace('https://www.dcs.shef.ac.uk/intranet/archive/campus/'+year+'/projects/ug/', "")
                    filename = file.replace(".pdf", "")
#                     print(filename)
                    if (check(filename+'.txt', file, file_list, downloaded)):
                        download_pdf(dis_url, file)
        
        
#         if (dis_none == False):
#             write_file(topic_path+filename+'.txt', topic)
#             write_file(abstract_path+filename+'.txt', abstract)

# %%
def load_filename():
    file_list = []
    dirPath = './ug_dataset/topic/'
    files = [f for f in os.listdir(dirPath) if os.path.isfile(os.path.join(dirPath, f))]
    files = sorted(files)
    for fname in files:
        if ('txt' not in fname):
            continue
        file_list.append(fname)
    return file_list

# %%
file_list = load_filename()
print(len(file_list))
# Out:
# 1192

# %%
def load_downloaded():
    downloaded = []
    dirPath = './pdf_file/'
    files = [f for f in os.listdir(dirPath) if os.path.isfile(os.path.join(dirPath, f))]
    files = sorted(files)
    for fname in files:
        if ('pdf' not in fname):
            continue
        downloaded.append(fname)
    return downloaded

# %%
downloaded = load_downloaded()
print(len(downloaded))
# Out:
# 1019

# %%
# save_db(rows)

# %%
years_1 = ['2017_2018', '2016_2017', '2015_2016', '2014_2015', '2013_2014', '2012_2013', '2011_2012', '2010_2011',
        '2009_2010']
years_2 = ['2008_2009', '2007_2008', '2006_2007', '2005_2006', '2004_2005', '2003_2004', '2002_2003',
        '2001_2002', '2000_2001']

# %%
for y in years_1:
    print(y)
    scraping_1(y, file_list, downloaded)
# Out:
# 2017_2018
# Babatunde Adeola
# Benjamin Askew
# David Bakun
# Stoyan Balabanov
# Vlad Balanescu
# Daniel Bayley
# Heather Bell
# Frazer Bennett Wilford
# Andreea-Camelia-Simona Bertea
# Tayla Blackman
# Harry Bold
# Callum Booth
# Kristofer Box
# Matthew Burman
# Robert Carter
# Antoine Chammas
# Kar Chan
# Vincent Chan
# Ganga Chana
# Aftab Chaudhary
# Junjin Chen
# Muhammad Chishty
# Grace Clare
# Harrison Cooper
# Rufus Cope
# Benjamin Cornforth
# Joseph D'Souza
# Manvir Dhinse
# Stefana Dobrea
# Samuel Donnan
# Rajeev Galaiya
# William Garside
# Alexandros Gkigkolian
# William Goldsworthy
# Jack Han
# Sarah Hardcastle
# Georgia Hardy
# James Harvey
# Danny Heard
# Matthew Holey
# Harry Howarth
# Alexis Ioannou
# Gurjit Jheeta
# Daniel Jones
# Tomasz Jurewicz
# Elliot Lewis
# Tebby Maritim
# Antonios Marketos
# Joseph Mason
# Christopher McIntyre
# Blayze Millward
# James Milton
# Fernando Montero Perez
# David Moodie
# Stephanie Morrissey
# Afolabi Nathan-Marsh
# Victoria Neal
# Manh Tri Nguyen
# Henry Noble
# Christiana Odysseos
# Adam Orr
# Aiden Page
# Owain Parry
# Hiren Patel
# Adam Phillips
# Daria Potapova
# Paras Raikundlia
# Greta Ramaneckaite
# Michal Ratajczak
# James Roberts
# Euan Rochester
# Giorgio Rumore
# Andrejs Ruzencevs
# Patrick Sambrook
# Sebastian Sas Mangel
# Jongmin Seo
# Mingqian Shi
# Muhammad Shuja
# Niall Stevenson
# John Sumner
# Jodi Swift
# Tom Thomas-Litman
# Hristiyan Trifonov
# Andrew Tyler
# Antria Vasileiou
# Joshua Vigar
# Jack Walker
# Matthew Walker
# Benjamin Wallace
# Wen Ting Wang
# James Webb
# Ian Williams
# Jack Williamson
# Chung Lam Yip
# Ho lam Yu
# Ningjia Yu
# Tao Zhang
# Ping Zhou
# 2016_2017
# Mohammad Ali
# Noor Alwatani
# Adam Antos
# Aaron Ayres
# Jingjing Bai
# Matthew Barber
# George Baron
# Petar Barzev
# Nishal Bathia
# Shreyans Bhansali
# Joshua Blease
# Michael Bodunrin
# Moritz Bohm
# Tom Borcherds
# Anthony Borrett
# Kieran Brady
# William Burscough
# Rafael Casabianca
# Joshua Case
# Joseph Chung
# Man Chung
# Patrick Clark
# Benjamin Clegg
# Martin Cnobel
# Andrew Cook
# Connor Copeland
# William Dawson
# Jack Deadman
# Samuel Dickinson
# Razvan Dragoi
# Robert Ede
# Hend Elghazaly
# Afamefuna Ezechukwu
# Rebecca Fields
# Matheus Gomes
# Bharat Modhwadia
# John Noel
# start download: u0jn.pdf
# <Response [200]>
# download finish
# Emmanuel Ogunshile
# start download: u0eo.pdf
# <Response [200]>
# download finish
# Benjamin Outram
# start download: u0bo.pdf
# <Response [200]>
# download finish
# Katan Patel
# start download: u0kp.pdf
# <Response [200]>
# download finish
# Nilesh Patel
# start download: u0np.pdf
# <Response [200]>
# download finish
# Matthew Pennington
# start download: u0mp.pdf
# <Response [200]>
# download finish
# Reena Pindoria
# start download: u0rp.pdf
# <Response [200]>
# download finish
# Ross Pointon
# start download: u0rp2.pdf
# <Response [200]>
# download finish
# Kevin Randall
# start download: u0kr.pdf
# <Response [200]>
# download finish
# Samuel Robinson
# start download: u9sr.pdf
# <Response [200]>
# download finish
# Sarah Rogers
# start download: u8sr.pdf
# <Response [200]>
# download finish
# Michael Sadler
# start download: u0ms3.pdf
# <Response [200]>
# download finish
# Spyridon Samothrakis
# start download: u9ss2.pdf
# <Response [200]>
# download finish
# Adam Shadbolt
# start download: u0as2.pdf
# <Response [200]>
# download finish
# Elshad Shadoobuccus
# start download: u0es2.pdf
# <Response [200]>
# download finish
# Thomas Singer
# start download: u9ts.pdf
# <Response [200]>
# download finish
# Michael Smart
# start download: u0ms2.pdf
# <Response [200]>
# download finish
# Matthew South
# start download: u0ms4.pdf
# <Response [200]>
# download finish
# Thomas Stainthorpe
# start download: u0ts.pdf
# <Response [200]>
# download finish
# Craig Swatman
# start download: u0cs.pdf
# <Response [200]>
# download finish
# Christopher Taylor
# start download: u9cjt.pdf
# <Response [200]>
# download finish
# Christopher Thomson
# start download: u0ct.pdf
# <Response [200]>
# download finish
# Markos Vratimos
# start download: u9mv.pdf
# <Response [200]>
# download finish
# Edward Waterhouse
# start download: u0nw.pdf
# <Response [200]>
# download finish
# Paul A Watson
# Simon White
# start download: u9sdw.pdf
# <Response [200]>
# download finish
# Henry Widd
# start download: u8hjw.pdf
# <Response [200]>
# download finish
# Daniel Wood
# start download: u9dw.pdf
# <Response [200]>
# download finish
# Wai Yuen
# start download: u9wpy.pdf
# <Response [200]>
# download finish
# 2001_2002
# David Adams
# start download: u9da.pdf
# <Response [200]>
# download finish
# Matthew Adams
# start download: u9mla.pdf
# <Response [200]>
# download finish
# Shawkat Assrafally
# start download: u9sra.pdf
# <Response [200]>
# download finish
# Stephanie Auty
# start download: u9sma.pdf
# <Response [200]>
# download finish
# Mark Bagnall
# start download: u9mab.pdf
# <Response [200]>
# download finish
# Stephen Barwood
# start download: u9sdb.pdf
# <Response [200]>
# download finish
# Stephen Bottomley
# start download: u9sjb.pdf
# <Response [200]>
# download finish
# Mark Brabin
# start download: u8mjb.pdf
# <Response [200]>
# download finish
# Terry Carter
# start download: u9tsc.pdf
# <Response [200]>
# download finish
# Christopher Cartmell
# start download: u7cjc.pdf
# <Response [200]>
# download finish
# Pierrot Casel
# start download: u1pc2.pdf
# <Response [200]>
# download finish
# Siew Chew
# start download: u1sc.pdf
# <Response [200]>
# download finish
# Simon Coakley
# start download: u9stc.pdf
# <Response [200]>
# download finish
# Stephen Connolly
# start download: u1sc2.pdf
# <Response [200]>
# download finish
# James Cross
# start download: u9jac.pdf
# <Response [200]>
# download finish
# Andrew Cubbon
# start download: u9arc.pdf
# <Response [200]>
# download finish
# Matthew Dootson
# start download: u9mpd.pdf
# <Response [200]>
# download finish
# Benjamin Drury
# start download: u8bjd.pdf
# <Response [200]>
# download finish
# Matthew Dudbridge
# start download: u9mjd.pdf
# <Response [200]>
# download finish
# Michael Edwards
# start download: u1me.pdf
# <Response [200]>
# download finish
# Gethin Evans
# start download: u8ge.pdf
# <Response [200]>
# download finish
# Matthew Fergusson
# start download: u8mjf.pdf
# <Response [200]>
# download finish
# Richard Francis
# start download: u9rmf.pdf
# <Response [200]>
# download finish
# Matthew Fraser
# start download: u9mif.pdf
# <Response [200]>
# download finish
# Jonathan Gent
# start download: u9jmg.pdf
# <Response [200]>
# download finish
# Harjeet Gill
# start download: u9hsg.pdf
# <Response [200]>
# download finish
# Andrew Granville
# start download: u9arg.pdf
# <Response [200]>
# download finish
# Benjamin Griffiths
# start download: u9bdg.pdf
# <Response [200]>
# download finish
# Christopher Grimble
# start download: u9cjg.pdf
# <Response [200]>
# download finish
# Matthew Hackett
# start download: u9mjh.pdf
# <Response [200]>
# download finish
# Robert Ham
# start download: u9rah.pdf
# <Response [200]>
# download finish
# Robert Harlow
# start download: u9rjh.pdf
# <Response [200]>
# download finish
# Matthew Haughton
# start download: u9mjvh.pdf
# <Response [200]>
# download finish
# Matthew Hobbs
# start download: u9msh.pdf
# <Response [200]>
# download finish
# Kasper Hunt
# start download: u9kjh.pdf
# <Response [200]>
# download finish
# Glyn Jeffries
# start download: u9gdj.pdf
# <Response [200]>
# download finish
# Andrew Keith
# start download: u9asmk.pdf
# <Response [200]>
# download finish
# Hing Fai Ko
# start download: u9fk.pdf
# <Response [200]>
# download finish
# Chee Koo
# start download: u1ck.pdf
# <Response [200]>
# download finish
# Xavier Langevin
# start download: u1xl.pdf
# <Response [200]>
# download finish
# Karen Lees
# start download: u9kvl.pdf
# <Response [200]>
# download finish
# James Leigh
# start download: u9jdl.pdf
# <Response [200]>
# download finish
# Viktoria Maier
# start download: u9vm.pdf
# <Response [200]>
# download finish
# Ian Makin
# start download: u9irm.pdf
# <Response [200]>
# download finish
# Geoffrey Marchment
# start download: u9gm.pdf
# <Response [200]>
# download finish
# Alasdair McLeay
# start download: u9ajm2.pdf
# <Response [200]>
# download finish
# Roger Mensah
# start download: u9rkm.pdf
# <Response [200]>
# download finish
# Rowan Merewood
# start download: u9rpm.pdf
# <Response [200]>
# download finish
# Ian Munday
# start download: u9ism.pdf
# <Response [200]>
# download finish
# Havina Mungun
# start download: u9hm.pdf
# <Response [200]>
# download finish
# Jeevanath Nagendra
# start download: u9jn.pdf
# <Response [200]>
# download finish
# William Newton
# start download: u8wrn.pdf
# <Response [200]>
# download finish
# Stuart Painter
# start download: u9snp.pdf
# <Response [200]>
# download finish
# Jemika Patel
# start download: u9jp.pdf
# <Response [200]>
# download finish
# Rui Pereira
# start download: u9rmsp.pdf
# <Response [200]>
# download finish
# Kevin Race
# start download: u9kr.pdf
# <Response [200]>
# download finish
# Christopher Regan
# start download: u9cmr.pdf
# <Response [200]>
# download finish
# Graham Richmond
# start download: u9gr.pdf
# <Response [200]>
# download finish
# Peter Rigby
# start download: u9psr.pdf
# <Response [200]>
# download finish
# Samrinder Sahota
# start download: u8sks.pdf
# <Response [200]>
# download finish
# Ian Simpson
# start download: u9ids.pdf
# <Response [200]>
# download finish
# Edward Smith
# start download: u9ers.pdf
# <Response [200]>
# download finish
# Samantha Smith
# start download: u9srs.pdf
# <Response [200]>
# download finish
# Stuart Stevenson
# start download: u1ss.pdf
# <Response [200]>
# download finish
# Mark Tice
# start download: u9mt.pdf
# <Response [200]>
# download finish
# Addi To
# start download: u9ayyt.pdf
# <Response [200]>
# download finish
# Stephen Vernon
# start download: u9srv.pdf
# <Response [200]>
# download finish
# Carlo De Vita
# start download: u1cdv.pdf
# <Response [200]>
# download finish
# Neil Walkinshaw
# start download: u9nw.pdf
# <Response [200]>
# download finish
# Michael Wall
# start download: u9mrw.pdf
# <Response [200]>
# download finish
# Amanda Watkinson
# start download: u9ajw.pdf
# <Response [200]>
# download finish
# Paul Whysall
# start download: u9pnw.pdf
# <Response [200]>
# download finish
# Andrew Williamson
# start download: u9aw.pdf
# <Response [200]>
# download finish
# Richard Wilson
# start download: u9rjw.pdf
# <Response [200]>
# download finish
# Stephen Woodbyrne
# start download: u9sw2.pdf
# <Response [200]>
# download finish
# Joss Wright
# start download: u9jaew.pdf
# <Response [200]>
# download finish
# 2000_2001
# Michael Adele
# start download: u8mja.pdf
# <Response [200]>
# download finish
# Ehtsham Akhtar
# start download: u8ea.pdf
# <Response [200]>
# download finish
# Lee Armstrong
# start download: u8lja.pdf
# <Response [200]>
# download finish
# Thomas Ashford
# start download: u8tja.pdf
# <Response [200]>
# download finish
# Jack Bamford
# start download: u8jb.pdf
# <Response [200]>
# download finish
# Paul Bye
# start download: u8pab.pdf
# <Response [200]>
# download finish
# Christopher Bygrave
# start download: u8csb.pdf
# <Response [200]>
# download finish
# David Carrington
# start download: u8djc.pdf
# <Response [200]>
# download finish
# Christopher Chong
# start download: u8cytc.pdf
# <Response [200]>
# download finish
# Andrew Clark
# start download: u8arc.pdf
# <Response [200]>
# download finish
# Alex Collins
# start download: u8aec.pdf
# <Response [200]>
# download finish
# Robert Cullen
# start download: u7rc.pdf
# <Response [200]>
# download finish
# Stephen Dann
# start download: u8spd.pdf
# <Response [200]>
# download finish
# Michael Davies
# start download: u8mcd.pdf
# <Response [200]>
# download finish
# Stephen Davison
# start download: u8smdd.pdf
# <Response [200]>
# download finish
# Sarah Deighton
# start download: u8sld.pdf
# <Response [200]>
# download finish
# Nicholas Farrell
# start download: u8ndf.pdf
# <Response [200]>
# download finish
# Richard Fletcher
# start download: u8rgf.pdf
# <Response [200]>
# download finish
# Nicholas Graham
# start download: u7nahg.pdf
# <Response [200]>
# download finish
# Adam Hamer
# start download: u8ajh2.pdf
# <Response [200]>
# download finish
# Matthew Hersee
# start download: u8msh.pdf
# <Response [200]>
# download finish
# Daniel Hooker
# start download: u8djh.pdf
# <Response [200]>
# download finish
# Adam Johnson
# start download: u8aj.pdf
# <Response [200]>
# download finish
# Michael Jones
# start download: u8mej.pdf
# <Response [200]>
# download finish
# Robert Kelly
# start download: u7rik.pdf
# <Response [200]>
# download finish
# Philip Le Gros
# start download: u7plg.pdf
# <Response [200]>
# download finish
# Cheon-Joo Lee
# start download: u8cjl.pdf
# <Response [200]>
# download finish
# Alexis Lendaris
# start download: u7al.pdf
# <Response [200]>
# download finish
# Stephen Levin
# start download: u8sjl.pdf
# <Response [200]>
# download finish
# Owain Lewis
# start download: u8orl.pdf
# <Response [200]>
# download finish
# Kjartan Malthe-Sorenssen
# start download: u8kms.pdf
# <Response [200]>
# download finish
# David Martin
# start download: u7dram.pdf
# <Response [200]>
# download finish
# Robert Maslen
# start download: u8rem.pdf
# <Response [200]>
# download finish
# Paul Masters
# start download: u7pm.pdf
# <Response [200]>
# download finish
# Stephen McCurry
# start download: u8sm.pdf
# <Response [200]>
# download finish
# David Meakin
# start download: u7dpm.pdf
# <Response [200]>
# download finish
# Adam Medcalf
# start download: u8ajm.pdf
# <Response [200]>
# download finish
# Andrew Moss
# start download: u7am2.pdf
# <Response [200]>
# download finish
# Andrew Mulvenna
# start download: u8arm.pdf
# <Response [200]>
# download finish
# Michael Newton
# start download: u8mpn.pdf
# <Response [200]>
# download finish
# David O'Brien
# start download: u7djo.pdf
# <Response [200]>
# download finish
# James Oates
# start download: u8jo.pdf
# <Response [200]>
# download finish
# Simon Payne
# start download: u8smp.pdf
# <Response [200]>
# download finish
# Thomas Price
# start download: u8tjp.pdf
# <Response [200]>
# download finish
# Robert Purchase
# start download: u8rp.pdf
# <Response [200]>
# download finish
# Graham Self
# start download: u8gds.pdf
# <Response [200]>
# download finish
# Alexis Shirtliff
# start download: u8as.pdf
# <Response [200]>
# download finish
# Owen Smith
# start download: u8oas.pdf
# <Response [200]>
# download finish
# Robert Smith
# start download: u8rms.pdf
# <Response [200]>
# download finish
# Andrew Steele
# start download: u8aks.pdf
# <Response [200]>
# download finish
# Joseph Stevens
# start download: u8jps.pdf
# <Response [200]>
# download finish
# David Stoker
# start download: u8dss.pdf
# <Response [200]>
# download finish
# Lee Sunter
# start download: u8ls.pdf
# <Response [200]>
# download finish
# Andrew Swingewood
# start download: u8ajs.pdf
# <Response [200]>
# download finish
# Lay May Tan
# start download: u0lt.pdf
# <Response [200]>
# download finish
# Emmanuel Tanguy
# start download: u0et.pdf
# <Response [200]>
# download finish
# Christopher Thomson
# start download: u8cdt.pdf
# <Response [200]>
# download finish
# Mark Urmston
# start download: u8mou.pdf
# <Response [200]>
# download finish
# David Vivash
# start download: u8dav.pdf
# <Response [200]>
# download finish
# Duncan Watson
# start download: u7dww.pdf
# <Response [200]>
# download finish
# Simon Wilkins
# start download: u8smw.pdf
# <Response [200]>
# download finish
# Adam Wyles
# start download: u8aww.pdf
# <Response [200]>
# download finish
# Kamil Zaki
# start download: u0kz.pdf
# <Response [200]>
# download finish
